# %%
import polyline

# %%
import googlemaps
import json

import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt
import seaborn as sns
import math

import folium

import subprocess

sns.set_style("darkgrid")

# %%
gclient = googlemaps.Client(YOUR_API_KEY)

# %%
#start = "76 Henry Street, Brooklyn, NY, USA"
#finish = "55 3rd Avenue, New York, NY, USA"

start = (40.749718, -74.002950)
finish = (40.726795, -73.996951)

# %%
direct = gclient.directions(origin=start, destination=finish, mode="bicycling")
direct_road = gclient.directions(origin=start, destination=finish)

# %%
my_points = polyline.decode(direct[0]['overview_polyline']['points'])
my_points_road = polyline.decode(direct_road[0]['overview_polyline']['points'])

# %%
my_df = pd.DataFrame(my_points)
my_df.rename(columns={0:'start station latitude', 1:'start station longitude'}, inplace=True)
my_df_road = pd.DataFrame(my_points_road)
my_df_road.rename(columns={0:'start station latitude', 1:'start station longitude'}, inplace=True)

# %%
my_df.head()
# Out:
#    start station latitude  start station longitude
# 0                40.74968                -74.00298
# 1                40.74886                -74.00102
# 2                40.74842                -73.99999
# 3                40.74747                -74.00065
# 4                40.74625                -74.00155

# %%
my_interpolation = gclient.snap_to_roads(my_points, interpolate=True)

# %%
my_interpolation_road = gclient.snap_to_roads(my_points_road, interpolate=True)

# %%
my_df_interpolation = pd.DataFrame(my_interpolation)

# %%
my_df_interpolation_road = pd.DataFrame(my_interpolation_road)

# %%
my_df_interpolation['start station latitude'] = my_df_interpolation['location'].apply(lambda x: x.get('latitude'))
my_df_interpolation['start station longitude'] = my_df_interpolation['location'].apply(lambda x: x.get('longitude'))

# %%
my_df_interpolation_road['start station latitude'] = my_df_interpolation_road['location'].apply(lambda x: x.get('latitude'))
my_df_interpolation_road['start station longitude'] = my_df_interpolation_road['location'].apply(lambda x: x.get('longitude'))

# %%
my_df.head()
# Out:
#    start station latitude  start station longitude
# 0                40.74968                -74.00298
# 1                40.74886                -74.00102
# 2                40.74842                -73.99999
# 3                40.74747                -74.00065
# 4                40.74625                -74.00155

# %%
sg_map = folium.Map(location=[40.71993, -73.99594], zoom_start=13)

# %%
def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe
my_df_road.apply(plotDot, axis = 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# dtype: object

# %%
#car directions
sg_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map2 = folium.Map(location=[40.71993, -73.99594], zoom_start=13)

def plotDot2(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map2)

my_df_interpolation.apply(plotDot2, axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 162    None
# 163    None
# 164    None
# 165    None
# 166    None
# 167    None
# 168    None
# 169    None
# 170    None
# 171    None
# 172    None
# 173    None
# 174    None
# 175    None
# 176    None
# 177    None
# 178    None
# 179    None
# 180    None
# 181    None
# 182    None
# 183    None
# 184    None
# 185    None
# 186    None
# 187    None
# 188    None
# 189    None
# 190    None
# 191    None
# dtype: object

# %%
#interpolated bike directions
sg_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map3 = folium.Map(location=[40.71993, -73.99594], zoom_start=13)

def plotDot3(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map3)

my_df.apply(plotDot3, axis = 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# dtype: object

# %%
#bike directions
sg_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map4 = folium.Map(location=[40.71993, -73.99594], zoom_start=13)

def plotDot3(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map4)

my_df_interpolation_road.apply(plotDot3, axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 120    None
# 121    None
# 122    None
# 123    None
# 124    None
# 125    None
# 126    None
# 127    None
# 128    None
# 129    None
# 130    None
# 131    None
# 132    None
# 133    None
# 134    None
# 135    None
# 136    None
# 137    None
# 138    None
# 139    None
# 140    None
# 141    None
# 142    None
# 143    None
# 144    None
# 145    None
# 146    None
# 147    None
# 148    None
# 149    None
# dtype: object

# %%
#car directions interpolated
sg_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_df_interpolation_road.head()
# Out:
#                                             location  originalIndex  \
# 0  {u'latitude': 40.749680706, u'longitude': -74....            0.0
# 1  {u'latitude': 40.7496009, u'longitude': -74.00...            NaN
# 2  {u'latitude': 40.7496009, u'longitude': -74.00...            NaN
# 3  {u'latitude': 40.7493787, u'longitude': -74.00...            NaN
# 4  {u'latitude': 40.7493787, u'longitude': -74.00...            NaN
#
#                        placeId  start station latitude  \
# 0  ChIJF7XvDrdZwokR54rw_C3inSU               40.749681
# 1  ChIJF7XvDrdZwokR54rw_C3inSU               40.749601
# 2  ChIJ73nvE7dZwokRS0m8X8vfYPA               40.749601
# 3  ChIJ73nvE7dZwokRS0m8X8vfYPA               40.749379
# 4  ChIJuc-CFbdZwokRX20CQh5rktQ               40.749379
#
#    start station longitude
# 0               -74.002979
# 1               -74.002792
# 2               -74.002792
# 3               -74.002264
# 4               -74.002264

# %%
# get paths between all stations
# join start and stop times of trips to this dataframe
# interpolate times and lats/longitudes
# filter dataframe for each minute (second?), plot all the points, take a screenshot

# %%
#COPY BIKE DATA GATHERING HERE

# %%
#prepare data for loading
mypath = "C:\Users\Bryan\Documents\GitHub\Springboard\Capstone Project\Data\\"
dataFiles = [f for f in listdir(mypath) if isfile(join(mypath,f))]
dataFrames = []

inputDtypeDict = {'tripduration': np.int64,
                  #'starttime': np.datetime64,
                  #'stoptime': np.datetime64,
                  'start station id': np.int64,
                  'start station name': np.string_,
                  'start station longitude': np.float64,
                  'end station id': np.int64,
                  'end station name': np.string_,
                  'end station latitude': np.float64,
                  'end station longitude': np.float64,
                  'bikeid': np.int64,
                  'usertype': np.string_,
                  'birth year': np.string_,
                  'gender': np.int64,
                  'start next station id': np.int64
                  }

# %%
#column headers change with newer files... deal with this later
#dataFiles = dataFiles[:38]
dataFiles = dataFiles[:13]
print dataFiles
# Out:
# ['2013-07 - Citi Bike trip data.csv', '2013-08 - Citi Bike trip data.csv', '2013-09 - Citi Bike trip data.csv', '2013-10 - Citi Bike trip data.csv', '2013-11 - Citi Bike trip data.csv', '2013-12 - Citi Bike trip data.csv', '2014-01 - Citi Bike trip data.csv', '2014-02 - Citi Bike trip data.csv', '2014-04 - Citi Bike trip data.csv', '2014-05 - Citi Bike trip data.csv', '2014-06 - Citi Bike trip data.csv', '2014-07 - Citi Bike trip data.csv', '2014-08 - Citi Bike trip data.csv']

# %%
#load data into n dataframes
for f in dataFiles:
    data_df = pd.read_csv(mypath + f, dtype=inputDtypeDict, parse_dates=['starttime', 'stoptime'], infer_datetime_format=True)
    print "File " + f + " has " + str(len(data_df)) + " records"
    dataFrames.append(data_df)
# Out:
# File 2013-07 - Citi Bike trip data.csv has 843416 records
# File 2013-08 - Citi Bike trip data.csv has 1001958 records
# File 2013-09 - Citi Bike trip data.csv has 1034359 records
# File 2013-10 - Citi Bike trip data.csv has 1037712 records
# File 2013-11 - Citi Bike trip data.csv has 675774 records
# File 2013-12 - Citi Bike trip data.csv has 443966 records
# File 2014-01 - Citi Bike trip data.csv has 300400 records
# File 2014-02 - Citi Bike trip data.csv has 224736 records
# File 2014-04 - Citi Bike trip data.csv has 670780 records
# File 2014-05 - Citi Bike trip data.csv has 866117 records
# File 2014-06 - Citi Bike trip data.csv has 936880 records
# File 2014-07 - Citi Bike trip data.csv has 968842 records
# File 2014-08 - Citi Bike trip data.csv has 963489 records

# %%
#join all dataframes into single dataframe
allTrips_df = pd.concat(dataFrames)
print "Final file has " + str(len(allTrips_df)) + " records"
# Out:
# Final file has 9968429 records

# %%
#isolate records that indicate that a rebalancing occured
allTrips_df.sort_values(['bikeid', 'starttime'], inplace=True)
allTrips_df['start next station id'] = allTrips_df['start station id'].shift(-1)
rebalancing_df = allTrips_df[allTrips_df['end station id'] != allTrips_df['start next station id']].copy()

# %%
#take the trips from a single bike
allTripsOneBike = allTrips_df[allTrips_df['bikeid'] == 14529].copy()

# %%
allTripsOneBike.sort_values('starttime', inplace=True)

# %%
allTripsOneBike = allTripsOneBike.reset_index()

# %%
allTripsOneBike
# Out:
#        index  tripduration           starttime            stoptime  \
# 0      15139          1562 2013-07-01 21:28:12 2013-07-01 21:54:14
# 1      21956           621 2013-07-02 09:49:10 2013-07-02 09:59:31
# 2      23877          1055 2013-07-02 11:55:56 2013-07-02 12:13:31
# 3      30610           494 2013-07-02 17:24:40 2013-07-02 17:32:54
# 4      31217           649 2013-07-02 17:37:30 2013-07-02 17:48:19
# 5      32096           689 2013-07-02 17:56:08 2013-07-02 18:07:37
# 6      39223           961 2013-07-02 23:32:16 2013-07-02 23:48:17
# 7      39821           655 2013-07-03 02:54:40 2013-07-03 03:05:35
# 8      42675          1008 2013-07-03 08:36:55 2013-07-03 08:53:43
# 1753                  462.0
# 1754                  402.0
# 1755                  490.0
# 1756                  484.0
# 1757                  305.0
# 1758                  325.0
# 1759                  379.0
# 1760                  326.0
# 1761                  223.0
# 1762                  237.0
# 1763                  127.0
# 1764                  151.0
# 1765                  147.0
#
# [1766 rows x 17 columns]

# %%
my_df_interpolation_road.loc[0,'time'] = allTripsOneBike.loc[0,'starttime']

# %%
my_df_interpolation_road.loc[len(my_df_interpolation_road)-1,'time'] = allTripsOneBike.loc[0,'stoptime']

# %%
my_df_interpolation_road
# Out:
#                                               location  originalIndex  \
# 0    {u'latitude': 40.749680706, u'longitude': -74....            0.0
# 1    {u'latitude': 40.7496009, u'longitude': -74.00...            NaN
# 2    {u'latitude': 40.7496009, u'longitude': -74.00...            NaN
# 3    {u'latitude': 40.7493787, u'longitude': -74.00...            NaN
# 4    {u'latitude': 40.7493787, u'longitude': -74.00...            NaN
# 5    {u'latitude': 40.7492792, u'longitude': -74.00...            NaN
# 6    {u'latitude': 40.7492792, u'longitude': -74.00...            NaN
# 7    {u'latitude': 40.7491579, u'longitude': -74.00...            NaN
# 8    {u'latitude': 40.7491579, u'longitude': -74.00...            NaN
# 9    {u'latitude': 40.7490966, u'longitude': -74.00...            NaN
# 10   {u'latitude': 40.7490966, u'longitude': -74.00...            NaN
# 11   {u'latitude': 40.7490684, u'longitude': -74.00...            NaN
# 12   {u'latitude': 40.7490684, u'longitude': -74.00...            NaN
# 13   {u'latitude': 40.748893, u'longitude': -74.001...            NaN
# 14   {u'latitude': 40.748893, u'longitude': -74.001...            NaN
# 15   {u'latitude': 40.7488566, u'longitude': -74.00...            1.0
# 16   {u'latitude': 40.7488561, u'longitude': -74.00...            NaN
# 17   {u'latitude': 40.7488561, u'longitude': -74.00...            NaN
# 18   {u'latitude': 40.7488186, u'longitude': -74.00...            NaN
# 19   {u'latitude': 40.7488186, u'longitude': -74.00...            NaN
# 20   {u'latitude': 40.7484192, u'longitude': -73.99...            NaN
# 21   {u'latitude': 40.7484192, u'longitude': -73.99...            NaN
# 22   {u'latitude': 40.7482002, u'longitude': -73.99...            NaN
# 23   {u'latitude': 40.7482002, u'longitude': -73.99...            NaN
# 24   {u'latitude': 40.7481095031, u'longitude': -73...            2.0
# 25   {u'latitude': 40.7481083, u'longitude': -73.99...            NaN
# 26   {u'latitude': 40.7481083, u'longitude': -73.99...            NaN
# 27   {u'latitude': 40.7480553, u'longitude': -73.99...            NaN
# 28   {u'latitude': 40.7480553, u'longitude': -73.99...            NaN
# 29   {u'latitude': 40.7478855, u'longitude': -73.99...            NaN
# ..                                                 ...            ...
# 120  {u'latitude': 40.7297345, u'longitude': -74.00...            NaN
# 121  {u'latitude': 40.7297314607, u'longitude': -74...           21.0
# 122  {u'latitude': 40.7296583, u'longitude': -74.00...            NaN
# 123  {u'latitude': 40.7296583, u'longitude': -74.00...            NaN
# 124  {u'latitude': 40.7296333, u'longitude': -74.00...            NaN
# 125  {u'latitude': 40.7296307409, u'longitude': -74...           22.0
# 126  {u'latitude': 40.7296168, u'longitude': -74.00...            NaN
# 127  {u'latitude': 40.7296026, u'longitude': -74.00...            NaN
# 128  {u'latitude': 40.7296026, u'longitude': -74.00...            NaN
# 129  {u'latitude': 40.729601742, u'longitude': -74....           23.0
# 130  {u'latitude': 40.7294022, u'longitude': -74.00...            NaN
# 131  {u'latitude': 40.7294022, u'longitude': -74.00...            NaN
# 132  {u'latitude': 40.7294018605, u'longitude': -74...           24.0
# 133  {u'latitude': 40.729187, u'longitude': -74.001...            NaN
# 134  {u'latitude': 40.729187, u'longitude': -74.001...            NaN
# 135  {u'latitude': 40.7288134, u'longitude': -74.00...           25.0
# 136  {u'latitude': 40.7288134, u'longitude': -74.00...            NaN
# 137  {u'latitude': 40.7284387, u'longitude': -73.99...            NaN
# 138  {u'latitude': 40.7284387, u'longitude': -73.99...            NaN
# 139  {u'latitude': 40.7280718, u'longitude': -73.99...           26.0
# 140  {u'latitude': 40.7280718, u'longitude': -73.99...            NaN
# 141  {u'latitude': 40.7276785, u'longitude': -73.99...            NaN
# 142  {u'latitude': 40.7276785, u'longitude': -73.99...            NaN
# 143  {u'latitude': 40.727371, u'longitude': -73.997...            NaN
# 144  {u'latitude': 40.727371, u'longitude': -73.997...            NaN
# 145  {u'latitude': 40.7273699641, u'longitude': -73...           27.0
# 146  {u'latitude': 40.7269325, u'longitude': -73.99...            NaN
# 147  {u'latitude': 40.7269325, u'longitude': -73.99...            NaN
# 148  {u'latitude': 40.7269294832, u'longitude': -73...           28.0
# 149  {u'latitude': 40.7267391436, u'longitude': -73...           29.0
#
#                          placeId  start station latitude  \
# 0    ChIJF7XvDrdZwokR54rw_C3inSU               40.749681
# 1    ChIJF7XvDrdZwokR54rw_C3inSU               40.749601
# 2    ChIJ73nvE7dZwokRS0m8X8vfYPA               40.749601
# 3    ChIJ73nvE7dZwokRS0m8X8vfYPA               40.749379
# 4    ChIJuc-CFbdZwokRX20CQh5rktQ               40.749379
# 5    ChIJuc-CFbdZwokRX20CQh5rktQ               40.749279
# 6    ChIJeawNP7dZwokR090opuiNpV4               40.749279
# 7    ChIJeawNP7dZwokR090opuiNpV4               40.749158
# 8    ChIJr3ikOLdZwokR9-EbKNCfjH4               40.749158
# 9    ChIJr3ikOLdZwokR9-EbKNCfjH4               40.749097
# 10   ChIJn9p_R7dZwokRY_ISgUOfaws               40.749097
# 11   ChIJn9p_R7dZwokRY_ISgUOfaws               40.749068
# 12   ChIJQ44SSLdZwokRI6nWHqjdOpM               40.749068
# 13   ChIJQ44SSLdZwokRI6nWHqjdOpM               40.748893
# 14   ChIJhz2cSbdZwokRyfLowbQ0jIM               40.748893
# 15   ChIJhz2cSbdZwokRyfLowbQ0jIM               40.748857
# 16   ChIJhz2cSbdZwokRyfLowbQ0jIM               40.748856
# 17   ChIJgX_US7dZwokREvf_eIRp4VU               40.748856
# 18   ChIJgX_US7dZwokREvf_eIRp4VU               40.748819
# 2                 -74.002792                 NaT
# 3                 -74.002264                 NaT
# 4                 -74.002264                 NaT
# 5                 -74.002027                 NaT
# 6                 -74.002027                 NaT
# 7                 -74.001739                 NaT
# 8                 -74.001739                 NaT
# 9                 -74.001593                 NaT
# 10                -74.001593                 NaT
# 11                -74.001526                 NaT
# 12                -74.001526                 NaT
# 13                -74.001109                 NaT
# 14                -74.001109                 NaT
# 15                -74.001022                 NaT
# 16                -74.001021                 NaT
# 17                -74.001021                 NaT
# 18                -74.000933                 NaT
# 19                -74.000933                 NaT
# 20                -73.999994                 NaT
# 21                -73.999994                 NaT
# 22                -73.999440                 NaT
# 23                -73.999440                 NaT
# 24                -73.999210                 NaT
# 25                -73.999207                 NaT
# 26                -73.999207                 NaT
# 27                -73.999073                 NaT
# 28                -73.999073                 NaT
# 29                -73.998699                 NaT
# ..                       ...                 ...
# 120               -74.002187                 NaT
# 121               -74.002185                 NaT
# 122               -74.002145                 NaT
# 123               -74.002145                 NaT
# 124               -74.002123                 NaT
# 125               -74.002119                 NaT
# 126               -74.002099                 NaT
# 127               -74.002070                 NaT
# 128               -74.002070                 NaT
# 129               -74.002068                 NaT
# 130               -74.001669                 NaT
# 131               -74.001669                 NaT
# 132               -74.001669                 NaT
# 133               -74.001190                 NaT
# 134               -74.001190                 NaT
# 135               -74.000431                 NaT
# 136               -74.000431                 NaT
# 137               -73.999671                 NaT
# 138               -73.999671                 NaT
# 139               -73.998972                 NaT
# 140               -73.998972                 NaT
# 141               -73.998173                 NaT
# 142               -73.998173                 NaT
# 143               -73.997552                 NaT
# 144               -73.997552                 NaT
# 145               -73.997550                 NaT
# 146               -73.996676                 NaT
# 147               -73.996676                 NaT
# 148               -73.996679                 NaT
# 149               -73.996838 2013-07-01 21:54:14
#
# [150 rows x 6 columns]

# %%
my_df_interpolation_road.interpolate(method='linear', axis=0)
# Out:
#                                               location  originalIndex  \
# 0    {u'latitude': 40.749680706, u'longitude': -74....       0.000000
# 1    {u'latitude': 40.7496009, u'longitude': -74.00...       0.066667
# 2    {u'latitude': 40.7496009, u'longitude': -74.00...       0.133333
# 3    {u'latitude': 40.7493787, u'longitude': -74.00...       0.200000
# 4    {u'latitude': 40.7493787, u'longitude': -74.00...       0.266667
# 5    {u'latitude': 40.7492792, u'longitude': -74.00...       0.333333
# 6    {u'latitude': 40.7492792, u'longitude': -74.00...       0.400000
# 7    {u'latitude': 40.7491579, u'longitude': -74.00...       0.466667
# 8    {u'latitude': 40.7491579, u'longitude': -74.00...       0.533333
# 9    {u'latitude': 40.7490966, u'longitude': -74.00...       0.600000
# 10   {u'latitude': 40.7490966, u'longitude': -74.00...       0.666667
# 11   {u'latitude': 40.7490684, u'longitude': -74.00...       0.733333
# 12   {u'latitude': 40.7490684, u'longitude': -74.00...       0.800000
# 13   {u'latitude': 40.748893, u'longitude': -74.001...       0.866667
# 14   {u'latitude': 40.748893, u'longitude': -74.001...       0.933333
# 130  ChIJcexZPpJZwokRntxMjaaIQLY               40.729402
# 131  ChIJx8RpGJJZwokRJBTCL0_zI7U               40.729402
# 132  ChIJx8RpGJJZwokRJBTCL0_zI7U               40.729402
# 133  ChIJx8RpGJJZwokRJBTCL0_zI7U               40.729187
# 134  ChIJp3L1HpJZwokRiOMGI3iq69M               40.729187
# 135  ChIJp3L1HpJZwokRiOMGI3iq69M               40.728813
# 136  ChIJ1wZX8JFZwokRmxu9hxad7Nc               40.728813
# 137  ChIJ1wZX8JFZwokRmxu9hxad7Nc               40.728439
# 138  ChIJRd6r55FZwokRjce3lw43sX0               40.728439
# 139  ChIJRd6r55FZwokRjce3lw43sX0               40.728072
# 140  ChIJN8Ck2ZFZwokRRhfpT9knhPU               40.728072
# 141  ChIJN8Ck2ZFZwokRRhfpT9knhPU               40.727678
# 142  ChIJB6mVKo5ZwokReVqXchkcQew               40.727678
# 143  ChIJB6mVKo5ZwokReVqXchkcQew               40.727371
# 144  ChIJneu20I9ZwokRl5YdQzbPOok               40.727371
# 145  ChIJneu20I9ZwokRl5YdQzbPOok               40.727370
# 146  ChIJneu20I9ZwokRl5YdQzbPOok               40.726932
# 147  ChIJkwKzyY9ZwokRVewOsv6tC0s               40.726932
# 148  ChIJkwKzyY9ZwokRVewOsv6tC0s               40.726929
# 149  ChIJkwKzyY9ZwokRVewOsv6tC0s               40.726739
#
#      start station longitude                time
# 0                 -74.002979 2013-07-01 21:28:12
# 1                 -74.002792                 NaT
# 2                 -74.002792                 NaT
# 3                 -74.002264                 NaT
# 4                 -74.002264                 NaT
# 5                 -74.002027                 NaT
# 6                 -74.002027                 NaT
# 7                 -74.001739                 NaT
# 8                 -74.001739                 NaT
# 9                 -74.001593                 NaT
# 10                -74.001593                 NaT
# 11                -74.001526                 NaT
# 12                -74.001526                 NaT
# 13                -74.001109                 NaT
# 14                -74.001109                 NaT
# 15                -74.001022                 NaT
# 16                -74.001021                 NaT
# 17                -74.001021                 NaT
# 18                -74.000933                 NaT
# 19                -74.000933                 NaT
# 20                -73.999994                 NaT
# 21                -73.999994                 NaT
# 22                -73.999440                 NaT
# 23                -73.999440                 NaT
# 24                -73.999210                 NaT
# 25                -73.999207                 NaT
# 26                -73.999207                 NaT
# 27                -73.999073                 NaT
# 28                -73.999073                 NaT
# 29                -73.998699                 NaT
# ..                       ...                 ...
# 120               -74.002187                 NaT
# 121               -74.002185                 NaT
# 122               -74.002145                 NaT
# 123               -74.002145                 NaT
# 124               -74.002123                 NaT
# 125               -74.002119                 NaT
# 126               -74.002099                 NaT
# 127               -74.002070                 NaT
# 128               -74.002070                 NaT
# 129               -74.002068                 NaT
# 130               -74.001669                 NaT
# 131               -74.001669                 NaT
# 132               -74.001669                 NaT
# 133               -74.001190                 NaT
# 134               -74.001190                 NaT
# 135               -74.000431                 NaT
# 136               -74.000431                 NaT
# 137               -73.999671                 NaT
# 138               -73.999671                 NaT
# 139               -73.998972                 NaT
# 140               -73.998972                 NaT
# 141               -73.998173                 NaT
# 142               -73.998173                 NaT
# 143               -73.997552                 NaT
# 144               -73.997552                 NaT
# 145               -73.997550                 NaT
# 146               -73.996676                 NaT
# 147               -73.996676                 NaT
# 148               -73.996679                 NaT
# 149               -73.996838 2013-07-01 21:54:14
#
# [150 rows x 6 columns]

# %%
temp_df = my_df_interpolation_road.copy()

# %%
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
temp_df = temp_df[['start station latitude', 'start station longitude', 'time']].drop_duplicates().reset_index()

# %%
temp_df.head()
# Out:
#    index  start station latitude  start station longitude                time
# 0      0               40.749681               -74.002979 2013-07-01 21:28:12
# 1      1               40.749601               -74.002792                 NaT
# 2      3               40.749379               -74.002264                 NaT
# 3      5               40.749279               -74.002027                 NaT
# 4      7               40.749158               -74.001739                 NaT

# %%
temp_df['dist'] = \
    haversine_np(temp_df['start station longitude'].shift(), temp_df['start station latitude'].shift(),
                 temp_df.loc[1:, 'start station longitude'], temp_df.loc[1:, 'start station latitude'])

# %%
temp_df['cumdist'] = temp_df['dist'].cumsum().fillna(0)

# %%
temp_df
# Out:
#     index  start station latitude  start station longitude  \
# 0       0               40.749681               -74.002979
# 1       1               40.749601               -74.002792
# 2       3               40.749379               -74.002264
# 3       5               40.749279               -74.002027
# 4       7               40.749158               -74.001739
# 5       9               40.749097               -74.001593
# 6      11               40.749068               -74.001526
# 7      13               40.748893               -74.001109
# 8      15               40.748857               -74.001022
# 9      16               40.748856               -74.001021
# 10     18               40.748819               -74.000933
# 11     20               40.748419               -73.999994
# 12     22               40.748200               -73.999440
# 13     24               40.748110               -73.999210
# 14     25               40.748108               -73.999207
# 15     27               40.748055               -73.999073
# 16     29               40.747885               -73.998699
# 17     31               40.747591               -73.998008
# 18     33               40.747204               -73.997097
# 19     35               40.747204               -73.997097
# 20     36               40.745999               -73.994277
# 21     38               40.745390               -73.994709
# 22     40               40.745390               -73.994709
# 23     41               40.744765               -73.995170
# 24     43               40.744103               -73.995643
# 25     45               40.744102               -73.995644
# 26     46               40.743890               -73.995803
# 27     48               40.743427               -73.996146
# 28     50               40.742813               -73.996600
# 29     52               40.742232               -73.997015
# ..    ...                     ...                      ...
# 58    103               40.731749               -74.003294
# 59    104               40.731748               -74.003293
# 60    106               40.731477               -74.003138
# 61    108               40.731159               -74.002952
# 62    109               40.731157               -74.002951
# 63    111               40.730938               -74.002823
# 64    113               40.730340               -74.002491
# 65    114               40.730336               -74.002489
# 66    116               40.729980               -74.002281
# 67    117               40.729977               -74.002280
# 68    119               40.729734               -74.002187
# 69    121               40.729731               -74.002185
# 70    122               40.729658               -74.002145
# 71    124               40.729633               -74.002123
# 72    125               40.729631               -74.002119
# 73    126               40.729617               -74.002099
# 74    127               40.729603               -74.002070
# 75    129               40.729602               -74.002068
# 76    130               40.729402               -74.001669
# 77    132               40.729402               -74.001669
# 78    133               40.729187               -74.001190
# 79    135               40.728813               -74.000431
# 80    137               40.728439               -73.999671
# 81    139               40.728072               -73.998972
# 82    141               40.727678               -73.998173
# 83    143               40.727371               -73.997552
# 84    145               40.727370               -73.997550
# 85    146               40.726932               -73.996676
# 86    148               40.726929               -73.996679
# 87    149               40.726739               -73.996838
#
#                   time      dist   cumdist
# 0  2013-07-01 21:28:12       NaN  0.000000
# 1                  NaT  0.018118  0.018118
# 2                  NaT  0.050862  0.068981
# 3                  NaT  0.022774  0.091755
# 4                  NaT  0.027770  0.119525
# 5                  NaT  0.014023  0.133548
# 6                  NaT  0.006460  0.140008
# 7                  NaT  0.040146  0.180154
# 8                  NaT  0.008338  0.188492
# 9                  NaT  0.000115  0.188607
# 10                 NaT  0.008522  0.197129
# 11                 NaT  0.090666  0.287794
# 12                 NaT  0.052622  0.340416
# 13                 NaT  0.021781  0.362197
# 14                 NaT  0.000289  0.362486
# 15                 NaT  0.012741  0.375227
# 16                 NaT  0.036693  0.411920
# 17                 NaT  0.066727  0.478647
# 18                 NaT  0.087929  0.566576
# 19                 NaT  0.000041  0.566616
# 20                 NaT  0.272570  0.839186
# 21                 NaT  0.076837  0.916023
# 22                 NaT  0.000005  0.916028
# 23                 NaT  0.079485  0.995513
# 24                 NaT  0.083738  1.079251
# 25                 NaT  0.000114  1.079366
# 26                 NaT  0.027052  1.106418
# 27                 NaT  0.059040  1.165458
# 28                 NaT  0.078165  1.243623
# 29                 NaT  0.073429  1.317052
# ..                 ...       ...       ...
# 58                 NaT  0.061431  2.620558
# 59                 NaT  0.000109  2.620668
# 60                 NaT  0.032771  2.653438
# 61                 NaT  0.038653  2.692092
# 62                 NaT  0.000227  2.692319
# 63                 NaT  0.026705  2.719023
# 64                 NaT  0.072083  2.791107
# 65                 NaT  0.000442  2.791548
# 66                 NaT  0.043299  2.834847
# 67                 NaT  0.000281  2.835128
# 68                 NaT  0.028094  2.863222
# 69                 NaT  0.000366  2.863588
# 70                 NaT  0.008798  2.872386
# 71                 NaT  0.003372  2.875758
# 72                 NaT  0.000417  2.876175
# 73                 NaT  0.002269  2.878444
# 74                 NaT  0.002922  2.881365
# 75                 NaT  0.000173  2.881539
# 76                 NaT  0.040270  2.921809
# 77                 NaT  0.000074  2.921883
# 78                 NaT  0.046819  2.968702
# 79                 NaT  0.076237  3.044939
# 80                 NaT  0.076325  3.121264
# 81                 NaT  0.071612  3.192877
# 82                 NaT  0.080256  3.273132
# 83                 NaT  0.062463  3.335596
# 84                 NaT  0.000209  3.335804
# 85                 NaT  0.088182  3.423986
# 86                 NaT  0.000397  3.424383
# 87 2013-07-01 21:54:14  0.025047  3.449430
#
# [88 rows x 6 columns]

# %%
temp_df.set_index('cumdist', inplace=True)

# %%
temp_df
# Out:
#           index  start station latitude  start station longitude  \
# cumdist
# 0.000000      0               40.749681               -74.002979
# 0.018118      1               40.749601               -74.002792
# 0.068981      3               40.749379               -74.002264
# 0.091755      5               40.749279               -74.002027
# 0.119525      7               40.749158               -74.001739
# 0.133548      9               40.749097               -74.001593
# 0.140008     11               40.749068               -74.001526
# 0.180154     13               40.748893               -74.001109
# 0.188492     15               40.748857               -74.001022
# 0.188607     16               40.748856               -74.001021
# 0.197129     18               40.748819               -74.000933
# 0.287794     20               40.748419               -73.999994
# 0.340416     22               40.748200               -73.999440
# 0.362197     24               40.748110               -73.999210
# 0.362486     25               40.748108               -73.999207
# 0.375227     27               40.748055               -73.999073
# 0.411920     29               40.747885               -73.998699
# 0.478647     31               40.747591               -73.998008
# 0.566576     33               40.747204               -73.997097
# 0.566616     35               40.747204               -73.997097
# 0.839186     36               40.745999               -73.994277
# 0.916023     38               40.745390               -73.994709
# 0.916028     40               40.745390               -73.994709
# 0.995513     41               40.744765               -73.995170
# 1.079251     43               40.744103               -73.995643
# 1.079366     45               40.744102               -73.995644
# 1.106418     46               40.743890               -73.995803
# 1.165458     48               40.743427               -73.996146
# 1.243623     50               40.742813               -73.996600
# 1.317052     52               40.742232               -73.997015
# ...         ...                     ...                      ...
# 2.620558    103               40.731749               -74.003294
# 2.620668    104               40.731748               -74.003293
# 2.653438    106               40.731477               -74.003138
# 2.692092    108               40.731159               -74.002952
# 2.692319    109               40.731157               -74.002951
# 2.719023    111               40.730938               -74.002823
# 2.791107    113               40.730340               -74.002491
# 2.791548    114               40.730336               -74.002489
# 2.834847    116               40.729980               -74.002281
# 2.835128    117               40.729977               -74.002280
# 2.863222    119               40.729734               -74.002187
# 2.863588    121               40.729731               -74.002185
# 2.872386    122               40.729658               -74.002145
# 2.875758    124               40.729633               -74.002123
# 2.876175    125               40.729631               -74.002119
# 2.878444    126               40.729617               -74.002099
# 2.881365    127               40.729603               -74.002070
# 2.881539    129               40.729602               -74.002068
# 2.921809    130               40.729402               -74.001669
# 2.921883    132               40.729402               -74.001669
# 2.968702    133               40.729187               -74.001190
# 3.044939    135               40.728813               -74.000431
# 3.121264    137               40.728439               -73.999671
# 3.192877    139               40.728072               -73.998972
# 3.273132    141               40.727678               -73.998173
# 3.335596    143               40.727371               -73.997552
# 3.335804    145               40.727370               -73.997550
# 3.423986    146               40.726932               -73.996676
# 3.424383    148               40.726929               -73.996679
# 3.449430    149               40.726739               -73.996838
#
#                         time      dist
# cumdist
# 0.000000 2013-07-01 21:28:12       NaN
# 0.018118                 NaT  0.018118
# 0.068981                 NaT  0.050862
# 0.091755                 NaT  0.022774
# 0.119525                 NaT  0.027770
# 0.133548                 NaT  0.014023
# 0.140008                 NaT  0.006460
# 0.180154                 NaT  0.040146
# 0.188492                 NaT  0.008338
# 0.188607                 NaT  0.000115
# 0.197129                 NaT  0.008522
# 0.287794                 NaT  0.090666
# 0.340416                 NaT  0.052622
# 0.362197                 NaT  0.021781
# 0.362486                 NaT  0.000289
# 0.375227                 NaT  0.012741
# 0.411920                 NaT  0.036693
# 0.478647                 NaT  0.066727
# 0.566576                 NaT  0.087929
# 0.566616                 NaT  0.000041
# 0.839186                 NaT  0.272570
# 0.916023                 NaT  0.076837
# 0.916028                 NaT  0.000005
# 0.995513                 NaT  0.079485
# 1.079251                 NaT  0.083738
# 1.079366                 NaT  0.000114
# 1.106418                 NaT  0.027052
# 1.165458                 NaT  0.059040
# 1.243623                 NaT  0.078165
# 1.317052                 NaT  0.073429
# ...                      ...       ...
# 2.620558                 NaT  0.061431
# 2.620668                 NaT  0.000109
# 2.653438                 NaT  0.032771
# 2.692092                 NaT  0.038653
# 2.692319                 NaT  0.000227
# 2.719023                 NaT  0.026705
# 2.791107                 NaT  0.072083
# 2.791548                 NaT  0.000442
# 2.834847                 NaT  0.043299
# 2.835128                 NaT  0.000281
# 2.863222                 NaT  0.028094
# 2.863588                 NaT  0.000366
# 2.872386                 NaT  0.008798
# 2.875758                 NaT  0.003372
# 2.876175                 NaT  0.000417
# 2.878444                 NaT  0.002269
# 2.881365                 NaT  0.002922
# 2.881539                 NaT  0.000173
# 2.921809                 NaT  0.040270
# 2.921883                 NaT  0.000074
# 2.968702                 NaT  0.046819
# 3.044939                 NaT  0.076237
# 3.121264                 NaT  0.076325
# 3.192877                 NaT  0.071612
# 3.273132                 NaT  0.080256
# 3.335596                 NaT  0.062463
# 3.335804                 NaT  0.000209
# 3.423986                 NaT  0.088182
# 3.424383                 NaT  0.000397
# 3.449430 2013-07-01 21:54:14  0.025047
#
# [88 rows x 5 columns]

# %%
a = temp_df['time'].interpolate(method='values')

# %%
#ARGH!
a
# Out:
# cumdist
# 0.000000   2013-07-01 21:28:12
# 0.018118                   NaT
# 0.068981                   NaT
# 0.091755                   NaT
# 0.119525                   NaT
# 0.133548                   NaT
# 0.140008                   NaT
# 0.180154                   NaT
# 0.188492                   NaT
# 0.188607                   NaT
# 0.197129                   NaT
# 0.287794                   NaT
# 0.340416                   NaT
# 0.362197                   NaT
# 0.362486                   NaT
# 0.375227                   NaT
# 0.411920                   NaT
# 0.478647                   NaT
# 0.566576                   NaT
# 0.566616                   NaT
# 0.839186                   NaT
# 0.916023                   NaT
# 0.916028                   NaT
# 0.995513                   NaT
# 1.079251                   NaT
# 1.079366                   NaT
# 1.106418                   NaT
# 1.165458                   NaT
# 1.243623                   NaT
# 1.317052                   NaT
#                    ...
# 2.620558                   NaT
# 2.620668                   NaT
# 2.653438                   NaT
# 2.692092                   NaT
# 2.692319                   NaT
# 2.719023                   NaT
# 2.791107                   NaT
# 2.791548                   NaT
# 2.834847                   NaT
# 2.835128                   NaT
# 2.863222                   NaT
# 2.863588                   NaT
# 2.872386                   NaT
# 2.875758                   NaT
# 2.876175                   NaT
# 2.878444                   NaT
# 2.881365                   NaT
# 2.881539                   NaT
# 2.921809                   NaT
# 2.921883                   NaT
# 2.968702                   NaT
# 3.044939                   NaT
# 3.121264                   NaT
# 3.192877                   NaT
# 3.273132                   NaT
# 3.335596                   NaT
# 3.335804                   NaT
# 3.423986                   NaT
# 3.424383                   NaT
# 3.449430   2013-07-01 21:54:14
# Name: time, dtype: datetime64[ns]
