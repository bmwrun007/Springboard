# %%
import polyline

# %%
import googlemaps
import json

import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

import matplotlib.pyplot as plt
import seaborn as sns
import math

import folium

import subprocess

sns.set_style("darkgrid")

# %%
gclient = googlemaps.Client('AIzaSyD7Ju48WPwymLx7iCdEpAZQ9pIKmt4ee_8')

# %%
start = "76 Henry Street, Brooklyn, NY, USA"
finish = "55 3rd Avenue, New York, NY, USA"

# %%
direct = gclient.directions(origin=start, destination=finish, mode="bicycling")
direct_road = gclient.directions(origin=start, destination=finish)

# %%
my_points = polyline.decode(direct[0]['overview_polyline']['points'])
my_points_road = polyline.decode(direct_road[0]['overview_polyline']['points'])

# %%
my_df = pd.DataFrame(my_points)
my_df.rename(columns={0:'start station latitude', 1:'start station longitude'}, inplace=True)
my_df_road = pd.DataFrame(my_points_road)
my_df_road.rename(columns={0:'start station latitude', 1:'start station longitude'}, inplace=True)

# %%
my_df.head()
# Out:
#    start station latitude  start station longitude
# 0                40.69855                -73.99248
# 1                40.69745                -73.99302
# 2                40.69744                -73.99289
# 3                40.69722                -73.99212
# 4                40.69704                -73.99144

# %%
my_interpolation = gclient.snap_to_roads(my_points, interpolate=True)

# %%
my_interpolation_road = gclient.snap_to_roads(my_points_road, interpolate=True)

# %%
my_df_interpolation = pd.DataFrame(my_interpolation)

# %%
my_df_interpolation_road = pd.DataFrame(my_interpolation_road)

# %%
my_df_interpolation['start station latitude'] = my_df_interpolation['location'].apply(lambda x: x.get('latitude'))
my_df_interpolation['start station longitude'] = my_df_interpolation['location'].apply(lambda x: x.get('longitude'))

# %%
my_df_interpolation_road['start station latitude'] = my_df_interpolation_road['location'].apply(lambda x: x.get('latitude'))
my_df_interpolation_road['start station longitude'] = my_df_interpolation_road['location'].apply(lambda x: x.get('longitude'))

# %%
my_df.head()
# Out:
#    start station latitude  start station longitude
# 0                40.69855                -73.99248
# 1                40.69745                -73.99302
# 2                40.69744                -73.99289
# 3                40.69722                -73.99212
# 4                40.69704                -73.99144

# %%
sg_map = folium.Map(location=[40.70993, -73.99594], zoom_start=13)

# %%
def plotDot(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map)

#use df.apply(,axis=1) to "iterate" through every row in your dataframe
my_df_road.apply(plotDot, axis = 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
#       ...
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# 47    None
# 48    None
# 49    None
# 50    None
# 51    None
# 52    None
# 53    None
# 54    None
# 55    None
# 56    None
# 57    None
# 58    None
# 59    None
# 60    None
# 61    None
# dtype: object

# %%
sg_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map.save('Image Pipe//polyline_mapped.html')

# %%
sg_map2 = folium.Map(location=[40.70993, -73.99594], zoom_start=13)

def plotDot2(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map2)

my_df_interpolation.apply(plotDot2, axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 291    None
# 292    None
# 293    None
# 294    None
# 295    None
# 296    None
# 297    None
# 298    None
# 299    None
# 300    None
# 301    None
# 302    None
# 303    None
# 304    None
# 305    None
# 306    None
# 307    None
# 308    None
# 309    None
# 310    None
# 311    None
# 312    None
# 313    None
# 314    None
# 315    None
# 316    None
# 317    None
# 318    None
# 319    None
# 320    None
# dtype: object

# %%
sg_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map3 = folium.Map(location=[40.70993, -73.99594], zoom_start=13)

def plotDot3(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map3)

my_df.apply(plotDot3, axis = 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
#       ...
# 56    None
# 57    None
# 58    None
# 59    None
# 60    None
# 61    None
# 62    None
# 63    None
# 64    None
# 65    None
# 66    None
# 67    None
# 68    None
# 69    None
# 70    None
# 71    None
# 72    None
# 73    None
# 74    None
# 75    None
# 76    None
# 77    None
# 78    None
# 79    None
# 80    None
# 81    None
# 82    None
# 83    None
# 84    None
# 85    None
# dtype: object

# %%
sg_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sg_map4 = folium.Map(location=[40.70993, -73.99594], zoom_start=13)

def plotDot3(point):
    '''input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map'''
    folium.CircleMarker(location=[point['start station latitude'], point['start station longitude']],
                        fill_color='red', radius=5, popup=str(point['start station latitude']) + " " + str(point['start station longitude']),
                        weight=0).add_to(sg_map4)

my_df_interpolation_road.apply(plotDot3, axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 250    None
# 251    None
# 252    None
# 253    None
# 254    None
# 255    None
# 256    None
# 257    None
# 258    None
# 259    None
# 260    None
# 261    None
# 262    None
# 263    None
# 264    None
# 265    None
# 266    None
# 267    None
# 268    None
# 269    None
# 270    None
# 271    None
# 272    None
# 273    None
# 274    None
# 275    None
# 276    None
# 277    None
# 278    None
# 279    None
# dtype: object

# %%
sg_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
#                                             location  originalIndex  \
# 0  {u'latitude': 40.6985502479, u'longitude': -73...            0.0
# 1  {u'latitude': 40.6981019, u'longitude': -73.99...            NaN
# 2  {u'latitude': 40.6981019, u'longitude': -73.99...            NaN
# 3  {u'latitude': 40.69745, u'longitude': -73.9930...            NaN
# 4  {u'latitude': 40.69745, u'longitude': -73.9930...            NaN
#
#                        placeId  start station latitude  \
# 0  ChIJ5zkduDdawokR8imBf_V9hFI               40.698550
# 1  ChIJ5zkduDdawokR8imBf_V9hFI               40.698102
# 2  ChIJWT1O2zdawokRnP4z2q4ENhk               40.698102
# 3  ChIJWT1O2zdawokRnP4z2q4ENhk               40.697450
# 4  ChIJ-Y_Z2TdawokRp1ZKwtzL9l0               40.697450
#
#    start station longitude
# 0               -73.992481
# 1               -73.992700
# 2               -73.992700
# 3               -73.993025
# 4               -73.993025

# %%
# get paths between all stations
# join start and stop times of trips to this dataframe
# interpolate times and lats/longitudes
# filter dataframe for each minute (second?), plot all the points, take a screenshots
